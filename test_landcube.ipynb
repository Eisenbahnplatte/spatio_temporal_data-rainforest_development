# %%
using Pkg
Pkg.activate(".")
Pkg.instantiate()
using YAXArrays
using Zarr
using Dates
# Out:
#   Activating project at `~/spatial-temporal-stuff/spatio_temporal_data-rainforest_development`
#     Updating registry at `~/.julia/registries/General.toml`
#    Installed Blosc_jll ─────────────── v1.21.4+0
#    Installed HypergeometricFunctions ─ v0.3.17
#    Installed DiffRules ─────────────── v1.15.1
#    Installed Adapt ─────────────────── v3.6.2
#    Installed IterTools ─────────────── v1.8.0
#    Installed Zarr ──────────────────── v0.9.0
#    Installed Preferences ───────────── v1.4.0
#    Installed Mocking ───────────────── v0.7.7
#    Installed OpenSSL_jll ───────────── v3.0.9+0
#    Installed DataAPI ───────────────── v1.15.0
#    Installed ArrowTypes ────────────── v2.2.2
#    Installed Parsers ───────────────── v2.7.0
#    Installed OnlineStatsBase ───────── v1.6.1
#    Installed ConcurrentUtilities ───── v2.2.0
#    Installed StaticArrays ──────────── v1.5.26
#    Installed PrecompileTools ───────── v1.1.2
#    Installed ConstructionBase ──────── v1.5.2
# ...

# %%
include("./rainforest_lib.jl")
using .RainforestLib
# Out:
# WARNING: replacing module RainforestLib.

# %%
lc = RainforestLib.load_full_datacube()
# Out:
# ┌ Warning: connection_limit no longer supported as a keyword argument; use `HTTP.set_default_connection_limit!(25)` before any requests are made or construct a shared pool via `POOL = HTTP.Pool(25)` and pass to each request like `pool=POOL` instead.
# └ @ HTTP.Connections ~/.julia/packages/HTTP/uAaAw/src/Connections.jl:434
# ┌ Warning: connection_limit no longer supported as a keyword argument; use `HTTP.set_default_connection_limit!(25)` before any requests are made or construct a shared pool via `POOL = HTTP.Pool(25)` and pass to each request like `pool=POOL` instead.
# └ @ HTTP.Connections ~/.julia/packages/HTTP/uAaAw/src/Connections.jl:434
# ┌ Warning: connection_limit no longer supported as a keyword argument; use `HTTP.set_default_connection_limit!(25)` before any requests are made or construct a shared pool via `POOL = HTTP.Pool(25)` and pass to each request like `pool=POOL` instead.
# └ @ HTTP.Connections ~/.julia/packages/HTTP/uAaAw/src/Connections.jl:434
# ...
